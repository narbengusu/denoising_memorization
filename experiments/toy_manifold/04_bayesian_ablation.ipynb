# %% [markdown]
# # Toy 1D manifold: Bayesian FR guidance ablation (v1 bootstrap vs v2 closed-form)
#
# Compares two ways of regularizing the k-NN Fisher-Rao assignment `q^beta(y)` against overfitting the
# finite-sample Laguerre partition:
#
# - **`bayesian_fr` (v1, bootstrap)**: `bayesian_fr.fisher_rao_energy_bb` -- Monte Carlo average of `B` draws
#   of a `Dirichlet(dirichlet_alpha)` prior over the k retrieved atoms, each combined with the data term into a
#   Gibbs posterior.
# - **`bayesian_fr_v2` (v2, closed-form)**: `bayesian_fr_v2.fisher_rao_energy_v2` -- places the Dirichlet prior
#   directly on the unknown local assignment `pi`, treats `kappa * q^beta(y)` as fractional evidence, and gets a
#   Dirichlet posterior in closed form (general Bayesian updating, Bissiri et al. 2016). Both the posterior mean
#   `q_bar = (alpha_0 + kappa*q)/a0` and the expected FR energy `E[I(q)] = a0/(a0+1) * I(q_bar)` are closed-form --
#   no sampling.
#
# `alpha_0` (v2) controls how strongly `q_bar` is pulled toward uniform (sparsity-preventing prior strength);
# `kappa` (v2) controls how much the plug-in evidence `q^beta(y)` is trusted (pseudo-count). v1's analogues are
# `dirichlet_alpha` (the bootstrap's Dirichlet concentration) and `B` (number of bootstrap draws -- more draws
# approximate the true Gibbs-posterior expectation more accurately, at proportionally higher cost, which is
# exactly the cost v2 is designed to avoid by being closed-form).
#
# **Compared**: wall-clock time per condition (`runtime_s`, saved to the results table) and performance
# (`mem_ratio`, `fidelity_mse`, same definitions as `02_fr_guidance.ipynb`).

# %%
import os, sys, time
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0, os.path.abspath("../../src"))
from guidance import driver, basic_fr, bayesian_fr, bayesian_fr_v2

REGIME = "normal"
N = int(os.environ.get("N_DATA", 20))
TAG = f"{REGIME}_N{N}"
ckpt = torch.load(f"checkpoints/score_{TAG}.pt", weights_only=False)
train_config = ckpt["config"]
d, device = train_config["d"], train_config["device"]
X_target = ckpt["X_target"].to(device)
u_target = ckpt["u_target"].to(device)

OUT_DIR = f"checkpoints/N{N}-{REGIME}"
os.makedirs(OUT_DIR, exist_ok=True)

print(f"regime={REGIME}  N={N}  d={d}, device={device}, N_data={X_target.shape[0]}, iters={train_config['iters']}")
print(f"outputs -> {OUT_DIR}/")
# Out:
# regime=normal  N=20  d=2, device=cpu, N_data=20, iters=50000
# outputs -> checkpoints/N20-normal/

# %%
class ScoreNet(nn.Module):
    def __init__(self, d, hidden, depth):
        super().__init__()
        self.input_proj = nn.Linear(d + 1, hidden)
        self.layers = nn.ModuleList([nn.Linear(hidden, hidden) for _ in range(depth * 2)])
        self.output_proj = nn.Linear(hidden, d)

    def forward(self, x, t):
        h = F.silu(self.input_proj(torch.cat([x, t[:, None]], dim=-1)))
        for i in range(0, len(self.layers), 2):
            r = F.silu(self.layers[i](h))
            r = self.layers[i + 1](r)
            h = h + r
        return self.output_proj(h)

net = ScoreNet(d, train_config["hidden"], train_config["depth"]).to(device)
net.load_state_dict(ckpt["net_state"])
net.eval()
print("Loaded score net.")
# Out:
# Loaded score net.

# %%
ADAPTIVE_CLIP = "adaptive_score_norm"   # sentinel for config["grad_clip"]: cap the guidance grad's
                                         # norm at ||score(z_t, t)|| instead of a fixed constant --
                                         # see score_norm_clip_fn below (same option as 02_fr_guidance.ipynb).

config = {
    "beta_min": train_config["beta_min"], "beta_max": train_config["beta_max"], "T": train_config["T"],
    "n_steps": 1000,
    "n_samples": 200,
    "seed": 10,
    "k_neighbors": 3,
    "ell": 1,
    "mem_ratio_threshold": 1 / 3,

    # "fixed" hyperparameters -- each may be a single value or a list of values to sweep
    "lam": [0.01, 0.1, 1.0],
    "grad_clip": [10000, ADAPTIVE_CLIP],
    "window": (0.5, 1.0),

    # v2 (bayesian_fr_v2, closed-form): alpha_0 = prior strength (uniformity-imposing),
    # kappa = evidence pseudo-count (how much q^beta(y) is trusted)
    "alpha_0_grid": [0.1, 1, 3, 10],
    "kappa_grid": [10],

    # v1 (bayesian_fr, bootstrap): dirichlet_alpha = bootstrap prior concentration,
    # B = number of bootstrap draws (more draws -> closer to the true Gibbs-posterior
    # expectation v2 gets in closed form, at proportionally higher cost)
    "bb_alpha_grid": [0.1, 1.0, 10.0],
    "bb_B_grid": [16, 64, 256],
}

def as_list(v):
    return v if isinstance(v, list) else [v]

def beta(t):
    return config["beta_min"] + t * (config["beta_max"] - config["beta_min"])

def alpha_bar(t):
    return torch.exp(-(config["beta_min"] * t + 0.5 * (config["beta_max"] - config["beta_min"]) * t ** 2))

def sigma2(t):
    return (1 - alpha_bar(t)).clamp(min=1e-4)

def g2(t):
    return beta(t)

# %% [markdown]
# ## Wire up the generic interface for sampling and guidance
#
# Same `base_step_fn`/`y_fn`/`step_scale_fn` as `02_fr_guidance.ipynb` -- identical reverse SDE step and
# denoiser, nothing about this ablation changes the sampler itself, only the guidance energy.

# %%
n_steps = config["n_steps"]
dt = config["T"] / n_steps
t_vec_holder = {"t": None}

def make_base_step_fn():
    def base_step_fn(z_t, step_idx):
        k = n_steps - step_idx
        t_vec = torch.full((z_t.shape[0],), (k + 1) * dt, device=device)
        t_vec_holder["t"] = t_vec
        with torch.no_grad():
            eps_hat = net(z_t, t_vec)
            score = -eps_hat / sigma2(t_vec)[:, None].sqrt()
            drift = -0.5 * beta(t_vec)[:, None] * z_t - beta(t_vec)[:, None] * score
            noise = beta(t_vec)[:, None].sqrt() * torch.randn_like(z_t) if k > 0 else 0
        return z_t - drift * dt + noise * dt ** 0.5
    return base_step_fn

def y_fn(z_t):
    t_vec = t_vec_holder["t"]
    eps_hat = net(z_t, t_vec)
    a = alpha_bar(t_vec)
    return (z_t - (1 - a)[:, None].sqrt() * eps_hat) / a[:, None].sqrt()

def score_norm_clip_fn(z_t):
    # Adaptive grad_clip (see 02_fr_guidance.ipynb): caps the guidance gradient's norm at
    # ||score(z_t, t)|| itself instead of one fixed constant for every x and every t.
    # driver.py's _resolve_clip_norm calls this with the current z_t whenever grad_clip is a
    # callable; t_vec_holder["t"] is already set by whichever step is currently running.
    t_vec = t_vec_holder["t"]
    eps_hat = net(z_t, t_vec)
    score = -eps_hat / sigma2(t_vec)[:, None].sqrt()
    return score.norm(dim=-1, keepdim=True)

def step_scale_fn(step_idx):
    k = n_steps - step_idx
    t_vec = torch.full((config["n_samples"],), (k + 1) * dt, device=device)
    return g2(t_vec)[:, None] * dt

# %% [markdown]
# ## Guidance energies: bayesian v1 (bootstrap) vs v2 (closed-form), ambient and projected
#
# Both retrieve the same `k_neighbors` nearest atoms via `basic_fr.ann_query` and pin `beta_t = sigma_t^2`, exactly
# as in `02_fr_guidance.ipynb`. Both the ambient (`unprojected`) and tangent-restricted (`projected`) energy
# factory are built for each method -- `make_guidance_fn` below picks the right one per `jacobian_name`.

# %%
index = basic_fr.build_flat_index(X_target)

def make_v1_energy_fn(dirichlet_alpha, B):
    return bayesian_fr.make_knn_bayesian_fr_energy_fn(
        index, config["k_neighbors"], lambda: sigma2(t_vec_holder["t"]),
        B=B, dirichlet_alpha=dirichlet_alpha)

def make_v1_projected_energy_fn(dirichlet_alpha, B):
    return bayesian_fr.make_knn_bayesian_projected_energy_fn(
        index, config["k_neighbors"], lambda: sigma2(t_vec_holder["t"]),
        B=B, dirichlet_alpha=dirichlet_alpha)

def make_v2_energy_fn(alpha_0, kappa):
    return bayesian_fr_v2.make_knn_bayesian_v2_fr_energy_fn(
        index, config["k_neighbors"], lambda: sigma2(t_vec_holder["t"]),
        alpha_0=alpha_0, kappa=kappa)

def make_v2_projected_energy_fn(alpha_0, kappa):
    return bayesian_fr_v2.make_knn_bayesian_v2_projected_energy_fn(
        index, config["k_neighbors"], lambda: sigma2(t_vec_holder["t"]),
        alpha_0=alpha_0, kappa=kappa)

# %% [markdown]
# ## Analytic tangent Jacobian
#
# Ground-truth tangent of `y = 0.6 sin(2x)`, identical to `02_fr_guidance.ipynb` -- evaluated at the x-coordinate
# of `y` itself. Rank 1 by construction, so this builds `projector_fn(y) -> P` directly.

# %%
def tangent_vec_from_u(u):
    t = torch.stack([torch.ones_like(u), 1.2 * torch.cos(2 * u)], dim=-1)
    return t / t.norm(dim=-1, keepdim=True)

def analytic_tangent_projector(y):
    u = y[:, 0].clamp(-3.2, 3.2)
    t = tangent_vec_from_u(u)
    return torch.einsum("bi,bj->bij", t, t)

JACOBIANS = {"unprojected": None, "projected": analytic_tangent_projector}

GRAD_CLIP_FNS = {ADAPTIVE_CLIP: score_norm_clip_fn}   # resolved to a callable at guidance-build time;
                                                       # any other grad_clip value passes through as the
                                                       # fixed scalar it already is (driver.py accepts both).

def resolve_grad_clip(grad_clip):
    return GRAD_CLIP_FNS.get(grad_clip, grad_clip)

def make_guidance_fn(method, jacobian_name, grad_clip, **hp):
    projector_fn = JACOBIANS[jacobian_name]
    if method == "bayesian_fr_v1":
        energy_fn = (make_v1_projected_energy_fn(hp["dirichlet_alpha"], hp["B"]) if projector_fn is not None
                     else make_v1_energy_fn(hp["dirichlet_alpha"], hp["B"]))
    elif method == "bayesian_fr_v2":
        energy_fn = (make_v2_projected_energy_fn(hp["alpha_0"], hp["kappa"]) if projector_fn is not None
                     else make_v2_energy_fn(hp["alpha_0"], hp["kappa"]))
    else:
        raise ValueError(method)
    grad_clip = resolve_grad_clip(grad_clip)
    if projector_fn is None:
        return driver.make_autograd_guidance_fn(y_fn, energy_fn, target_range=None, grad_clip=grad_clip)
    return driver.make_projected_guidance_fn(
        y_fn, energy_fn, projector_fn, target_range=None, grad_clip=grad_clip)

# %% [markdown]
# ## Metrics
#
# Identical to `02_fr_guidance.ipynb`: `mem_ratio` (fraction of samples whose nearest/2nd-nearest training-atom
# distance ratio falls below `mem_ratio_threshold`) and `fidelity_mse` (mean squared distance to the true
# `y = 0.6 sin(2x)` curve, over non-memorized samples only).

# %%
u_scan = torch.linspace(-4.0, 4.0, 4000, device=device)
curve_scan = torch.stack([u_scan, 0.6 * torch.sin(2 * u_scan)], dim=-1)

def dist_to_manifold(X):
    return torch.cdist(X, curve_scan).min(dim=1).values

def is_memorized(X, atoms, thresh):
    d2 = torch.cdist(X, atoms)
    top2 = torch.topk(d2, 2, largest=False, dim=1).values
    ratio = top2[:, 0] / top2[:, 1].clamp(min=1e-8)
    return ratio.lt(thresh)

def evaluate(X):
    mem = is_memorized(X, X_target, config["mem_ratio_threshold"])
    unmem = ~mem
    fidelity = dist_to_manifold(X[unmem]).pow(2).mean().item() if unmem.any() else float("nan")
    return {"mem_ratio": mem.float().mean().item(), "fidelity_mse": fidelity}

# %%
def run_condition(guidance_fn, lam=None, window=None):
    torch.manual_seed(config["seed"])
    z_init = torch.randn(config["n_samples"], d, device=device)
    t0 = time.perf_counter()
    if guidance_fn is None:
        x = z_init
        base_step_fn = make_base_step_fn()
        with torch.no_grad():
            for step_idx in range(1, n_steps + 1):
                x = base_step_fn(x, step_idx)
        runtime_s = time.perf_counter() - t0
        return x.detach(), runtime_s
    progress_lo, progress_hi = window
    z_final, _ = driver.guided_reverse_loop(
        z_init, n_steps, make_base_step_fn(), guidance_fn,
        progress_lo=progress_lo, progress_hi=progress_hi, ell=config["ell"], lam=lam,
        step_scale_fn=step_scale_fn)
    runtime_s = time.perf_counter() - t0
    return z_final.detach(), runtime_s

X_unguided, t_unguided = run_condition(None)
baseline = {"method": "unguided", "jacobian": "n/a", "runtime_s": t_unguided, **evaluate(X_unguided)}
print(baseline)
# Out:
# {'method': 'unguided', 'jacobian': 'n/a', 'runtime_s': 0.33550729195121676, 'mem_ratio': 0.5049999952316284, 'fidelity_mse': 0.0007398093002848327}

# %% [markdown]
# ## Full sweep: jacobian x v1 (`dirichlet_alpha` x `B`) and jacobian x v2 (`alpha_0` x `kappa`)
#
# Now crossed with `jacobian in {unprojected, projected}` so each method's own regularization hyperparameters
# are compared both in the full ambient space and restricted to the tangent, and further crossed with
# `FIXED_GRID` (`lam` x `grad_clip` x `window`, each from `config` via `as_list` -- a single value stays a
# 1-element grid, a list sweeps).

# %%
rows = [baseline]
samples_cache = {("unguided", "n/a"): X_unguided}

FIXED_GRID = [(lam, grad_clip, window)
              for lam in as_list(config["lam"])
              for grad_clip in as_list(config["grad_clip"])
              for window in as_list(config["window"])]

for jacobian_name in JACOBIANS:
    for dirichlet_alpha in config["bb_alpha_grid"]:
        for B in config["bb_B_grid"]:
            for lam, grad_clip, window in FIXED_GRID:
                guidance_fn = make_guidance_fn("bayesian_fr_v1", jacobian_name, grad_clip,
                                                dirichlet_alpha=dirichlet_alpha, B=B)
                X, runtime_s = run_condition(guidance_fn, lam=lam, window=window)
                row = {"method": "bayesian_fr_v1", "jacobian": jacobian_name, "dirichlet_alpha": dirichlet_alpha, "B": B,
                       "lam": lam, "grad_clip": grad_clip, "window": window,
                       "runtime_s": runtime_s, **evaluate(X)}
                rows.append(row)
                samples_cache[("bayesian_fr_v1", jacobian_name, dirichlet_alpha, B, lam, grad_clip, window)] = X
                print(row)

for jacobian_name in JACOBIANS:
    for alpha_0 in config["alpha_0_grid"]:
        for kappa in config["kappa_grid"]:
            for lam, grad_clip, window in FIXED_GRID:
                guidance_fn = make_guidance_fn("bayesian_fr_v2", jacobian_name, grad_clip,
                                                alpha_0=alpha_0, kappa=kappa)
                X, runtime_s = run_condition(guidance_fn, lam=lam, window=window)
                row = {"method": "bayesian_fr_v2", "jacobian": jacobian_name, "alpha_0": alpha_0, "kappa": kappa,
                       "lam": lam, "grad_clip": grad_clip, "window": window,
                       "runtime_s": runtime_s, **evaluate(X)}
                rows.append(row)
                samples_cache[("bayesian_fr_v2", jacobian_name, alpha_0, kappa, lam, grad_clip, window)] = X
                print(row)

df = pd.DataFrame(rows)
df.to_csv(f"{OUT_DIR}/bayesian_ablation_results.csv", index=False)
print(f"\n{len(df)} configs run.")
df
# Out:
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9590312909567729, 'mem_ratio': 0.15000000596046448, 'fidelity_mse': 0.001086298725567758}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.059949417016469, 'mem_ratio': 0.49000000953674316, 'fidelity_mse': 0.0005752952420152724}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0923859580652788, 'mem_ratio': 0.6800000071525574, 'fidelity_mse': 0.0007158556254580617}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1263548749266192, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.0007619250100106001}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0496230829739943, 'mem_ratio': 0.14499999582767487, 'fidelity_mse': 1.4483537673950195}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3004019160289317, 'mem_ratio': 0.2849999964237213, 'fidelity_mse': 0.0014376860344782472}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.3667167499661446, 'mem_ratio': 0.17000000178813934, 'fidelity_mse': 0.0011398335918784142}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2740456250030547, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.0006728479056619108}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.362521041999571, 'mem_ratio': 0.7300000190734863, 'fidelity_mse': 0.0006285177078098059}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.415623166016303, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.000679732474964112}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0768981669098139, 'mem_ratio': 0.10999999940395355, 'fidelity_mse': 1.2592430114746094}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.237551208003424, 'mem_ratio': 0.3199999928474426, 'fidelity_mse': 0.0014284206554293633}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.5585883329622447, 'mem_ratio': 0.11500000208616257, 'fidelity_mse': 0.0009913519024848938}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.178688957937993, 'mem_ratio': 0.4749999940395355, 'fidelity_mse': 0.0006274989573284984}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.0215034580323845, 'mem_ratio': 0.75, 'fidelity_mse': 0.0006658600177615881}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.858280749991536, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.0006392531213350594}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.276748124975711, 'mem_ratio': 0.10499999672174454, 'fidelity_mse': 1.2525136470794678}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.5330785419791937, 'mem_ratio': 0.3400000035762787, 'fidelity_mse': 0.001255513052456081}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2732989999931306, 'mem_ratio': 0.25, 'fidelity_mse': 0.0007893348811194301}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.351035333937034, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.0009415635140612721}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.1402421250240877, 'mem_ratio': 0.5950000286102295, 'fidelity_mse': 0.0006673229509033263}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4273202910553664, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.000987459090538323}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.1211689159972593, 'mem_ratio': 0.36000001430511475, 'fidelity_mse': 2.0228402614593506}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2128043330740184, 'mem_ratio': 0.2750000059604645, 'fidelity_mse': 0.0010345615446567535}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2960897500161082, 'mem_ratio': 0.20999999344348907, 'fidelity_mse': 0.0008203098550438881}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4625847920542583, 'mem_ratio': 0.41499999165534973, 'fidelity_mse': 0.0007077735499478877}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2894648750079796, 'mem_ratio': 0.550000011920929, 'fidelity_mse': 0.0007357450085692108}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4694619580404833, 'mem_ratio': 0.41499999165534973, 'fidelity_mse': 0.000682252284605056}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.3549783329945058, 'mem_ratio': 0.3050000071525574, 'fidelity_mse': 1.3205962181091309}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4821939580142498, 'mem_ratio': 0.29499998688697815, 'fidelity_mse': 0.001046528690494597}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.8389538339106366, 'mem_ratio': 0.23499999940395355, 'fidelity_mse': 0.0007331070955842733}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.15215924999211, 'mem_ratio': 0.5199999809265137, 'fidelity_mse': 0.0006857567350380123}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.9090136250015348, 'mem_ratio': 0.6200000047683716, 'fidelity_mse': 0.0010304576717317104}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.2287537079537287, 'mem_ratio': 0.5, 'fidelity_mse': 0.0006816469831392169}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.966568083036691, 'mem_ratio': 0.33000001311302185, 'fidelity_mse': 1.4996155500411987}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.0480520419077948, 'mem_ratio': 0.33500000834465027, 'fidelity_mse': 0.0011670389212667942}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0427816669689491, 'mem_ratio': 0.30000001192092896, 'fidelity_mse': 0.0007579356315545738}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2847259999252856, 'mem_ratio': 0.5, 'fidelity_mse': 0.0007373869302682579}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0638622920960188, 'mem_ratio': 0.6050000190734863, 'fidelity_mse': 0.0006710133166052401}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2587782500777394, 'mem_ratio': 0.42500001192092896, 'fidelity_mse': 0.0007654083892703056}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.161670416011475, 'mem_ratio': 0.33500000834465027, 'fidelity_mse': 1.0976455211639404}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3132587090367451, 'mem_ratio': 0.3149999976158142, 'fidelity_mse': 0.0009962377371266484}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.404231540975161, 'mem_ratio': 0.30000001192092896, 'fidelity_mse': 0.0006937735015526414}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.7663647079607472, 'mem_ratio': 0.4449999928474426, 'fidelity_mse': 0.0008009824086911976}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.4430579169420525, 'mem_ratio': 0.6100000143051147, 'fidelity_mse': 0.0005252741393633187}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4749212500173599, 'mem_ratio': 0.45500001311302185, 'fidelity_mse': 0.0007155979983508587}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.3630754170008004, 'mem_ratio': 0.35499998927116394, 'fidelity_mse': 0.9098410606384277}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.6893272079760209, 'mem_ratio': 0.28999999165534973, 'fidelity_mse': 0.0009527155198156834}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.8840201669372618, 'mem_ratio': 0.25999999046325684, 'fidelity_mse': 0.0007016690215095878}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.085139209055342, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.0005538218538276851}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.9919084169669077, 'mem_ratio': 0.5400000214576721, 'fidelity_mse': 0.0006719399825669825}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.281128542032093, 'mem_ratio': 0.46000000834465027, 'fidelity_mse': 0.0007035640301182866}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.883449082961306, 'mem_ratio': 0.3700000047683716, 'fidelity_mse': 0.7461288571357727}
# {'method': 'bayesian_fr_v1', 'jacobian': 'unprojected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.120588624966331, 'mem_ratio': 0.2549999952316284, 'fidelity_mse': 0.0009539700113236904}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2258524160133675, 'mem_ratio': 0.125, 'fidelity_mse': 0.001340591348707676}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1747264999430627, 'mem_ratio': 0.49000000953674316, 'fidelity_mse': 0.0005753517034463584}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0042752920417115, 'mem_ratio': 0.675000011920929, 'fidelity_mse': 0.0004929769784212112}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1623208749806508, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.0005490878829732537}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0202835409436375, 'mem_ratio': 0.18000000715255737, 'fidelity_mse': 1.4796993732452393}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1618378330022097, 'mem_ratio': 0.3100000023841858, 'fidelity_mse': 0.001251790439710021}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2132039590505883, 'mem_ratio': 0.11999999731779099, 'fidelity_mse': 0.001316749257966876}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4677974589867517, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.0006748116575181484}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.270662209019065, 'mem_ratio': 0.7599999904632568, 'fidelity_mse': 0.0006557189044542611}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4629546250216663, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.0007650643237866461}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.339007040951401, 'mem_ratio': 0.19499999284744263, 'fidelity_mse': 1.247079849243164}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3791180829284713, 'mem_ratio': 0.29499998688697815, 'fidelity_mse': 0.001512686489149928}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.8448423329973593, 'mem_ratio': 0.09000000357627869, 'fidelity_mse': 0.0011529108742251992}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.100724083953537, 'mem_ratio': 0.4749999940395355, 'fidelity_mse': 0.0006281863898038864}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.1154370419681072, 'mem_ratio': 0.7549999952316284, 'fidelity_mse': 0.0007451336132362485}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.1274776249192655, 'mem_ratio': 0.45500001311302185, 'fidelity_mse': 0.0006470638327300549}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.8177115409635007, 'mem_ratio': 0.2150000035762787, 'fidelity_mse': 1.09559166431427}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 0.1, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.129263750044629, 'mem_ratio': 0.33500000834465027, 'fidelity_mse': 0.0015133993001654744}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.5038869580021128, 'mem_ratio': 0.2750000059604645, 'fidelity_mse': 0.0008494589710608125}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.295346666011028, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.0009507419890724123}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.978997541940771, 'mem_ratio': 0.5600000023841858, 'fidelity_mse': 0.0006419949349947274}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3021525830263272, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.001013095723465085}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.1145570420194417, 'mem_ratio': 0.36000001430511475, 'fidelity_mse': 1.157220482826233}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3905247499933466, 'mem_ratio': 0.30000001192092896, 'fidelity_mse': 0.0011636328417807817}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.3381440000375733, 'mem_ratio': 0.22499999403953552, 'fidelity_mse': 0.0009052421082742512}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.5892640829551965, 'mem_ratio': 0.41499999165534973, 'fidelity_mse': 0.0007070743595249951}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2061260410118848, 'mem_ratio': 0.574999988079071, 'fidelity_mse': 0.0006027637282386422}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.399725417024456, 'mem_ratio': 0.4000000059604645, 'fidelity_mse': 0.0007108105928637087}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.20859954203479, 'mem_ratio': 0.32499998807907104, 'fidelity_mse': 1.057411551475525}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4963522920152172, 'mem_ratio': 0.3100000023841858, 'fidelity_mse': 0.0010933184530586004}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.9402564159827307, 'mem_ratio': 0.20999999344348907, 'fidelity_mse': 0.0006912978715263307}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.063164334045723, 'mem_ratio': 0.5099999904632568, 'fidelity_mse': 0.0006819181726314127}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.9048513330053538, 'mem_ratio': 0.6349999904632568, 'fidelity_mse': 0.0006398652330972254}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.155174917075783, 'mem_ratio': 0.47999998927116394, 'fidelity_mse': 0.0006969549576751888}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.85380962502677, 'mem_ratio': 0.3199999928474426, 'fidelity_mse': 0.9215118885040283}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 1.0, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.075601457967423, 'mem_ratio': 0.32499998807907104, 'fidelity_mse': 0.001217848272062838}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0537835829891264, 'mem_ratio': 0.25999999046325684, 'fidelity_mse': 0.0008994840318337083}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1728817919502035, 'mem_ratio': 0.5, 'fidelity_mse': 0.0007387896766886115}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9670622500125319, 'mem_ratio': 0.550000011920929, 'fidelity_mse': 0.0006600687629543245}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1407543749082834, 'mem_ratio': 0.4099999964237213, 'fidelity_mse': 0.0007351386011578143}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0556764169596136, 'mem_ratio': 0.33500000834465027, 'fidelity_mse': 1.1376466751098633}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 16, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1663971670204774, 'mem_ratio': 0.3050000071525574, 'fidelity_mse': 0.0011492219055071473}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2700608749873936, 'mem_ratio': 0.33500000834465027, 'fidelity_mse': 0.000748807389754802}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4771145830163732, 'mem_ratio': 0.44999998807907104, 'fidelity_mse': 0.0008037886582314968}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2780799999600276, 'mem_ratio': 0.5400000214576721, 'fidelity_mse': 0.00047266800538636744}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.6155021670274436, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.000716902082785964}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.2765324169304222, 'mem_ratio': 0.33000001311302185, 'fidelity_mse': 1.097067952156067}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 64, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.4430142500204965, 'mem_ratio': 0.2849999964237213, 'fidelity_mse': 0.0010541389929130673}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.0807731250533834, 'mem_ratio': 0.25, 'fidelity_mse': 0.0007218691753223538}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.404043958056718, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.000554849102627486}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 2.0055362500716, 'mem_ratio': 0.6349999904632568, 'fidelity_mse': 0.0005307059618644416}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.269746124977246, 'mem_ratio': 0.44999998807907104, 'fidelity_mse': 0.0007126586278900504}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.9132605409249663, 'mem_ratio': 0.3400000035762787, 'fidelity_mse': 0.8095674514770508}
# {'method': 'bayesian_fr_v1', 'jacobian': 'projected', 'dirichlet_alpha': 10.0, 'B': 256, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 2.0693530830321833, 'mem_ratio': 0.2549999952316284, 'fidelity_mse': 0.0010341035667806864}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.031082709087059, 'mem_ratio': 0.3199999928474426, 'fidelity_mse': 0.0007056856411509216}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2322414999362081, 'mem_ratio': 0.4950000047683716, 'fidelity_mse': 0.0007292672526091337}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.15283941605594, 'mem_ratio': 0.6050000190734863, 'fidelity_mse': 0.0003843077283818275}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3120463750092313, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.0007938686176203191}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.071216042037122, 'mem_ratio': 0.3400000035762787, 'fidelity_mse': 1.2017154693603516}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.194997041951865, 'mem_ratio': 0.3050000071525574, 'fidelity_mse': 0.0008537769317626953}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.1909944999497384, 'mem_ratio': 0.39500001072883606, 'fidelity_mse': 0.000663495622575283}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.331771833007224, 'mem_ratio': 0.4950000047683716, 'fidelity_mse': 0.0007295077666640282}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.1937127920100465, 'mem_ratio': 0.5699999928474426, 'fidelity_mse': 0.0006521219620481133}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2487406670115888, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.000751426094211638}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0357974590733647, 'mem_ratio': 0.42500001192092896, 'fidelity_mse': 0.8530480265617371}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2570937499403954, 'mem_ratio': 0.35499998927116394, 'fidelity_mse': 0.0008999998681247234}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0520673749269918, 'mem_ratio': 0.5299999713897705, 'fidelity_mse': 0.0006982734776102006}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2189731249818578, 'mem_ratio': 0.5, 'fidelity_mse': 0.0007360987365245819}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0743967500748113, 'mem_ratio': 0.6449999809265137, 'fidelity_mse': 0.0006122522754594684}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.3655682080425322, 'mem_ratio': 0.4749999940395355, 'fidelity_mse': 0.0007238833932206035}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0440977499820292, 'mem_ratio': 0.5249999761581421, 'fidelity_mse': 0.5722177028656006}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 3, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2114002080634236, 'mem_ratio': 0.42500001192092896, 'fidelity_mse': 0.0008188782958313823}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0327052910579368, 'mem_ratio': 0.5950000286102295, 'fidelity_mse': 0.0008350756834261119}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2109208329347894, 'mem_ratio': 0.5099999904632568, 'fidelity_mse': 0.0007245006854645908}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0285311249317601, 'mem_ratio': 0.7149999737739563, 'fidelity_mse': 0.0009031682857312262}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2251361249946058, 'mem_ratio': 0.48500001430511475, 'fidelity_mse': 0.0007172346813604236}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0267840409651399, 'mem_ratio': 0.6850000023841858, 'fidelity_mse': 0.1585657149553299}
# {'method': 'bayesian_fr_v2', 'jacobian': 'unprojected', 'alpha_0': 10, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1951682500075549, 'mem_ratio': 0.5799999833106995, 'fidelity_mse': 0.0006768832681700587}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9828422500286251, 'mem_ratio': 0.33000001311302185, 'fidelity_mse': 0.0007522479863837361}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.076221999945119, 'mem_ratio': 0.4950000047683716, 'fidelity_mse': 0.0007306293700821698}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.8665537920314819, 'mem_ratio': 0.6200000047683716, 'fidelity_mse': 0.0004234998777974397}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.022172666969709, 'mem_ratio': 0.4749999940395355, 'fidelity_mse': 0.000781020789872855}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.8501427919836715, 'mem_ratio': 0.3499999940395355, 'fidelity_mse': 1.316443681716919}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 0.1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.0576423750026152, 'mem_ratio': 0.3199999928474426, 'fidelity_mse': 0.0009494493715465069}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9610111250076443, 'mem_ratio': 0.41499999165534973, 'fidelity_mse': 0.0007110109436325729}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.165143333026208, 'mem_ratio': 0.4950000047683716, 'fidelity_mse': 0.0007309084758162498}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 1.0566429999889806, 'mem_ratio': 0.6050000190734863, 'fidelity_mse': 0.0007762921741232276}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.112694290932268, 'mem_ratio': 0.4650000035762787, 'fidelity_mse': 0.0007720302091911435}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.8511947500519454, 'mem_ratio': 0.3700000047683716, 'fidelity_mse': 0.4604876935482025}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 1, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.0426629580324516, 'mem_ratio': 0.36500000953674316, 'fidelity_mse': 0.0009035474504344165}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.8469775830162689, 'mem_ratio': 0.5049999952316284, 'fidelity_mse': 0.0007446385570801795}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.0403907919535413, 'mem_ratio': 0.5, 'fidelity_mse': 0.0007375204586423934}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9345919589977711, 'mem_ratio': 0.7149999737739563, 'fidelity_mse': 0.0007329352083615959}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.0391310839913785, 'mem_ratio': 0.4749999940395355, 'fidelity_mse': 0.0007162615656852722}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.8703662919579074, 'mem_ratio': 0.5199999809265137, 'fidelity_mse': 0.5896928310394287}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 3, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.1025643330067396, 'mem_ratio': 0.41499999165534973, 'fidelity_mse': 0.0008008114527910948}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.01, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9753318339353427, 'mem_ratio': 0.6100000143051147, 'fidelity_mse': 0.0008443779079243541}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.01, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.0672690840438008, 'mem_ratio': 0.5049999952316284, 'fidelity_mse': 0.0007180888205766678}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.1, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.9421551249688491, 'mem_ratio': 0.7049999833106995, 'fidelity_mse': 0.001024407334625721}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 0.1, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2592926248908043, 'mem_ratio': 0.4950000047683716, 'fidelity_mse': 0.0007080291397869587}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 1.0, 'grad_clip': 10000, 'window': (0.5, 1.0), 'runtime_s': 0.949295875034295, 'mem_ratio': 0.675000011920929, 'fidelity_mse': 0.36924096941947937}
# {'method': 'bayesian_fr_v2', 'jacobian': 'projected', 'alpha_0': 10, 'kappa': 10, 'lam': 1.0, 'grad_clip': 'adaptive_score_norm', 'window': (0.5, 1.0), 'runtime_s': 1.2972805419703946, 'mem_ratio': 0.5649999976158142, 'fidelity_mse': 0.000674162176437676}
#
# 157 configs run.
#              method     jacobian  runtime_s  mem_ratio  fidelity_mse  \
# 0          unguided          n/a   0.335507      0.505      0.000740
# 1    bayesian_fr_v1  unprojected   0.959031      0.150      0.001086
# 2    bayesian_fr_v1  unprojected   1.059949      0.490      0.000575
# 3    bayesian_fr_v1  unprojected   1.092386      0.680      0.000716
# 4    bayesian_fr_v1  unprojected   1.126355      0.480      0.000762
# ..              ...          ...        ...        ...           ...
# 152  bayesian_fr_v2    projected   1.067269      0.505      0.000718
# 153  bayesian_fr_v2    projected   0.942155      0.705      0.001024
# 154  bayesian_fr_v2    projected   1.259293      0.495      0.000708
# 155  bayesian_fr_v2    projected   0.949296      0.675      0.369241
# 156  bayesian_fr_v2    projected   1.297281      0.565      0.000674
#
#      dirichlet_alpha     B   lam            grad_clip      window  alpha_0  \
# 0                NaN   NaN   NaN                  NaN         NaN      NaN
# 1                0.1  16.0  0.01                10000  (0.5, 1.0)      NaN
# 2                0.1  16.0  0.01  adaptive_score_norm  (0.5, 1.0)      NaN
# 3                0.1  16.0  0.10                10000  (0.5, 1.0)      NaN
# 4                0.1  16.0  0.10  adaptive_score_norm  (0.5, 1.0)      NaN
# ..               ...   ...   ...                  ...         ...      ...
# 152              NaN   NaN  0.01  adaptive_score_norm  (0.5, 1.0)     10.0
# 153              NaN   NaN  0.10                10000  (0.5, 1.0)     10.0
# 154              NaN   NaN  0.10  adaptive_score_norm  (0.5, 1.0)     10.0
# 155              NaN   NaN  1.00                10000  (0.5, 1.0)     10.0
# 156              NaN   NaN  1.00  adaptive_score_norm  (0.5, 1.0)     10.0
#
#      kappa
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 152   10.0
# 153   10.0
# 154   10.0
# 155   10.0
# 156   10.0
#
# [157 rows x 12 columns]

# %% [markdown]
# ## Combined error and speed summary
#
# Same normalization as `02_fr_guidance.ipynb`: `combined_error = fidelity_mse/baseline_fidelity_mse * 0.01 +
# mem_ratio/baseline_mem_ratio` (2.0 = no change from unguided; lower is better on both axes). Now broken out by
# `(method, jacobian)`.

# %%
df["fidelity_rel"] = df["fidelity_mse"] / baseline["fidelity_mse"]
df["mem_rel"] = df["mem_ratio"] / baseline["mem_ratio"]
df["combined_error"] = df["fidelity_rel"] * 0.1 + df["mem_rel"]
df.to_csv(f"{OUT_DIR}/bayesian_ablation_results.csv", index=False)

guided = df[df["method"] != "unguided"]
print(f"baseline: runtime_s={baseline['runtime_s']:.2f}  combined_error=2.000 (mem_ratio={baseline['mem_ratio']:.3f}, fidelity_mse={baseline['fidelity_mse']:.4g})\n")

print("Speed summary (wall-clock seconds per 200-sample, 1000-step condition):")
print(guided.groupby(["method", "jacobian"])["runtime_s"].agg(["mean", "std", "min", "max"]).to_string())

print("\nPerformance summary (combined_error, lower is better):")
print(guided.groupby(["method", "jacobian"])["combined_error"].agg(["median", "min", "max"]).to_string())

print("\nBest config per (method, jacobian):")
best = guided.loc[guided.groupby(["method", "jacobian"])["combined_error"].idxmin()]
print(best[["method", "jacobian", "dirichlet_alpha", "B", "alpha_0", "kappa", "lam", "grad_clip", "window",
            "runtime_s", "mem_ratio", "fidelity_mse", "combined_error"]].to_string(index=False))
# Out:
# baseline: runtime_s=0.34  combined_error=2.000 (mem_ratio=0.505, fidelity_mse=0.0007398)
#
# Speed summary (wall-clock seconds per 200-sample, 1000-step condition):
#                                 mean       std       min       max
# method         jacobian
# bayesian_fr_v1 projected    1.546178  0.441189  0.967062  2.817712
#                unprojected  1.560823  0.442881  0.959031  2.858281
# bayesian_fr_v2 projected    1.015399  0.121225  0.846978  1.297281
#                unprojected  1.164095  0.105941  1.026784  1.365568
#
# Performance summary (combined_error, lower is better):
#                               median       min         max
# method         jacobian
# bayesian_fr_v1 projected    1.035006  0.334057  200.367354
#                unprojected  1.038350  0.361724  274.140126
# bayesian_fr_v2 projected    1.093427  0.755147  178.636721
#                unprojected  1.098715  0.719365  163.109110
#
# Best config per (method, jacobian):
#         method    jacobian  dirichlet_alpha     B  alpha_0  kappa  lam           grad_clip     window  runtime_s  mem_ratio  fidelity_mse  combined_error
# bayesian_fr_v1   projected              0.1 256.0      NaN    NaN 0.01               10000 (0.5, 1.0)   1.844842      0.090      0.001153        0.334057
# bayesian_fr_v1 unprojected              0.1 256.0      NaN    NaN 0.01               10000 (0.5, 1.0)   1.558588      0.115      0.000991        0.361724
# bayesian_fr_v2   projected              NaN   NaN      0.1   10.0 0.01               10000 (0.5, 1.0)   0.982842      0.330      0.000752        0.755147
# bayesian_fr_v2 unprojected              NaN   NaN      0.1   10.0 1.00 adaptive_score_norm (0.5, 1.0)   1.194997      0.305      0.000854        0.719365

# %% [markdown]
# ## Robustness gap: does v2 close the distance to v1 more when unprojected?
#
# The working hypothesis: v2's closed-form smoothing should help relatively MORE in the ambient (unprojected)
# energy, where the raw plug-in `q^beta(y)` is noisier (no tangent restriction narrowing which neighbor
# differences matter). `gap = median(combined_error, v1) - median(combined_error, v2)` per jacobian -- a smaller
# (or negative, meaning v2 wins outright) gap unprojected than projected would support the hypothesis.

# %%
median_by = guided.groupby(["method", "jacobian"])["combined_error"].median().unstack("method")
median_by["v1_minus_v2"] = median_by["bayesian_fr_v1"] - median_by["bayesian_fr_v2"]
print("Median combined_error by method x jacobian, and the v1-v2 gap (negative = v2 better):\n")
print(median_by.to_string())
# Out:
# Median combined_error by method x jacobian, and the v1-v2 gap (negative = v2 better):
#
# method       bayesian_fr_v1  bayesian_fr_v2  v1_minus_v2
# jacobian
# projected          1.035006        1.093427    -0.058421
# unprojected        1.038350        1.098715    -0.060365

# %% [markdown]
# ## Speed vs. performance scatter
#
# Each point is one hyperparameter config; color = method, marker = jacobian. v2 should sit systematically left
# of v1 (cheaper) at comparable `combined_error` regardless of jacobian, since it replaces v1's `B`-sample Monte
# Carlo average with a single closed-form expression; the interesting question is whether the unprojected (`^`)
# v2 points close the gap to v1 more than the projected (`o`) ones do.

# %%
fig, ax = plt.subplots(figsize=(7.5, 5.5))
colors = {"bayesian_fr_v1": "tab:purple", "bayesian_fr_v2": "tab:brown"}
markers = {"unprojected": "^", "projected": "o"}
for method, color in colors.items():
    for jacobian_name, marker in markers.items():
        sub = guided[(guided.method == method) & (guided.jacobian == jacobian_name)]
        ax.scatter(sub["runtime_s"], sub["combined_error"], color=color, marker=marker, alpha=0.75, s=55,
                   label=f"{method}/{jacobian_name}")
ax.axhline(2.0, color="gray", ls="--", lw=1, label="unguided baseline")
ax.axvline(baseline["runtime_s"], color="gray", ls=":", lw=1)
ax.set_xlabel("runtime_s (wall-clock, 200 samples x 1000 steps)")
ax.set_ylabel("combined_error (lower is better)")
ax.set_yscale("log")
ax.set_title(f"regime={REGIME} N={N}: speed vs. performance, v1 vs v2, unprojected vs projected")
ax.legend(fontsize=8)
plt.tight_layout()
plt.savefig(f"{OUT_DIR}/bayesian_speed_vs_performance.png", dpi=120)
plt.show()

# %% [markdown]
# ## Scatter view: unguided vs. best config per (method, jacobian)

# %%
GROUPS = [("bayesian_fr_v1", "unprojected"), ("bayesian_fr_v1", "projected"),
          ("bayesian_fr_v2", "unprojected"), ("bayesian_fr_v2", "projected")]

best_per_group = {}
for method, jacobian_name in GROUPS:
    sub = guided[(guided.method == method) & (guided.jacobian == jacobian_name)]
    if len(sub):
        best_per_group[(method, jacobian_name)] = sub.sort_values("combined_error").iloc[0]

picks = [("unguided", "n/a")] + list(best_per_group.keys())
N_COLS = 3
n_rows = (len(picks) + N_COLS - 1) // N_COLS
PANEL_W, PANEL_H = 9, 3.2
fig, axes = plt.subplots(n_rows, N_COLS, figsize=(PANEL_W * N_COLS, PANEL_H * n_rows), sharex=True, sharey=True)
axes = axes.flatten()
for ax, key in zip(axes, picks):
    if key == ("unguided", "n/a"):
        X, label = X_unguided, "unguided"
    else:
        method, jacobian_name = key
        row = best_per_group[key]
        hp_str = (f"dirichlet_alpha={row['dirichlet_alpha']:g}, B={int(row['B'])}" if method == "bayesian_fr_v1"
                  else f"alpha_0={row['alpha_0']:g}, kappa={row['kappa']:g}")
        hp_key = ((row["dirichlet_alpha"], row["B"]) if method == "bayesian_fr_v1"
                  else (row["alpha_0"], row["kappa"]))
        X = samples_cache[(method, jacobian_name, *hp_key, row["lam"], row["grad_clip"], row["window"])]
        label = f"{method}/{jacobian_name}\n{hp_str}\ncombined_error={row['combined_error']:.3f}, runtime_s={row['runtime_s']:.2f}"
    mem = is_memorized(X, X_target, config["mem_ratio_threshold"])
    ax.plot(curve_scan[:, 0].cpu(), curve_scan[:, 1].cpu(), color="lightgray", lw=2, zorder=0)
    ax.scatter(X[~mem, 0].cpu(), X[~mem, 1].cpu(), s=40, color="steelblue", alpha=0.55, label="not memorized", zorder=1)
    ax.scatter(X[mem, 0].cpu(), X[mem, 1].cpu(), s=40, color="tomato", alpha=0.55, label="memorized", zorder=2)
    ax.scatter(X_target[:, 0].cpu(), X_target[:, 1].cpu(), s=70, color="black", marker="x", label="train atoms", zorder=3)
    ax.set_title(label, fontsize=13)
    ax.legend(fontsize=10)
    pass
for ax in axes[len(picks):]:
    ax.axis("off")
fig.suptitle(f"regime={REGIME} N={N}: unguided vs. best config per (method, jacobian)", fontsize=15)
plt.tight_layout()
plt.savefig(f"{OUT_DIR}/bayesian_best_configs_scatter.png", dpi=120)
plt.show()
